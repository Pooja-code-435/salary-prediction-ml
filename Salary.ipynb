# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv(r"C:\Users\DELL\Downloads\Salary_Data.csv")

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %% [markdown]
# # INSPECTION

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.head(10)
# Out:
#     Age  Gender Education Level              Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's      Software Engineer                  5.0
# 1  28.0  Female        Master's           Data Analyst                  3.0
# 2  45.0    Male             PhD         Senior Manager                 15.0
# 3  36.0  Female      Bachelor's        Sales Associate                  7.0
# 4  52.0    Male        Master's               Director                 20.0
# 5  29.0    Male      Bachelor's      Marketing Analyst                  2.0
# 6  42.0  Female        Master's        Product Manager                 12.0
# 7  31.0    Male      Bachelor's          Sales Manager                  4.0
# 8  26.0  Female      Bachelor's  Marketing Coordinator                  1.0
# 9  38.0    Male             PhD       Senior Scientist                 10.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0
# 5   55000.0
# 6  120000.0
# 7   80000.0
# ...

# %%
df.tail()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0

# %%
df.tail(10)
# Out:
#        Age  Gender    Education Level                         Job Title  \
# 6694  27.0    Male        High School         Digital Marketing Manager
# 6695  33.0  Female  Bachelor's Degree         Content Marketing Manager
# 6696  28.0    Male                PhD              Sales Representative
# 6697  51.0  Female    Master's Degree  Senior Product Marketing Manager
# 6698  37.0    Male  Bachelor's Degree       Junior Sales Representative
# 6699  49.0  Female                PhD             Director of Marketing
# 6700  32.0    Male        High School                   Sales Associate
# 6701  30.0  Female  Bachelor's Degree                 Financial Manager
# 6702  46.0    Male    Master's Degree                 Marketing Manager
# 6703  26.0  Female        High School                   Sales Executive
#
#       Years of Experience    Salary
# 6694                  2.0   40000.0
# 6695                  7.0   90000.0
# 6696                  4.0   55000.0
# ...

# %%
df.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
df.isna().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array([32., 28., 45., 36., 52., 29., 42., 31., 26., 38., 48., 35., 40.,
#        27., 44., 33., 39., 25., 51., 34., 47., 30., 41., 37., 24., 43.,
#        50., 46., 49., 23., 53., nan, 61., 57., 62., 55., 56., 54., 60.,
#        58., 22., 21.])

# %%
col=df.columns
for i in col:
    print("Column:",i)
    print("Unique Values")
    print(df[i].unique())
    print("=============")
# Out:
# Column: Age
# Unique Values
# [32. 28. 45. 36. 52. 29. 42. 31. 26. 38. 48. 35. 40. 27. 44. 33. 39. 25.
#  51. 34. 47. 30. 41. 37. 24. 43. 50. 46. 49. 23. 53. nan 61. 57. 62. 55.
#  56. 54. 60. 58. 22. 21.]
# ...
# Column: Gender
# Unique Values
# ['Male' 'Female' nan 'Other']
# ...
# Column: Education Level
# Unique Values
# ["Bachelor's" "Master's" 'PhD' nan "Bachelor's Degree" "Master's Degree"
#  'High School' 'phD']
# ...
# Column: Job Title
# Unique Values
# ['Software Engineer' 'Data Analyst' 'Senior Manager' 'Sales Associate'
#  'Director' 'Marketing Analyst' 'Product Manager' 'Sales Manager'
#  'Marketing Coordinator' 'Senior Scientist' 'Software Developer'
#  'HR Manager' 'Financial Analyst' 'Project Manager' 'Customer Service Rep'
#  'Operations Manager' 'Marketing Manager' 'Senior Engineer'
#  'Data Entry Clerk' 'Sales Director' 'Business Analyst' 'VP of Operations'
#  'IT Support' 'Recruiter' 'Financial Manager' 'Social Media Specialist'
# ...

# %%
col=df.columns
for i in col:
    print("Column:",i)
    print("Value counts")
    print(df[i].value_counts())
    print("==================")
# Out:
# Column: Age
# Value counts
# 27.0    517
# 30.0    449
# 29.0    444
# 28.0    429
# 33.0    398
# 26.0    394
# 31.0    365
# 32.0    351
# 34.0    309
# 25.0    284
# 36.0    282
# 24.0    240
# 35.0    200
# 42.0    176
# 43.0    158
# 39.0    158
# 37.0    156
# 38.0    149
# 45.0    144
# 41.0    129
# 44.0    126
# 23.0    104
# 46.0    102
# 48.0     98
# 40.0     92
# 49.0     91
# 50.0     88
# 54.0     68
# 47.0     47
# 51.0     30
# 52.0     29
# 21.0     18
# 55.0     16
# 22.0     15
# 56.0     11
# 57.0      9
# 53.0      7
# 58.0      7
# 62.0      5
# 60.0      5
# 61.0      2
# Name: Age, dtype: int64
# ...
# Column: Gender
# Value counts
# Male      3674
# Female    3014
# Other       14
# Name: Gender, dtype: int64
# ...
# Column: Education Level
# Value counts
# Bachelor's Degree    2267
# Master's Degree      1573
# PhD                  1368
# Bachelor's            756
# High School           448
# Master's              288
# phD                     1
# ...

# %% [markdown]
# filtering conditions

# %%
df['Age']
# Out:
# 0       32.0
# 1       28.0
# 2       45.0
# 3       36.0
# 4       52.0
#         ...
# 6699    49.0
# 6700    32.0
# 6701    30.0
# 6702    46.0
# 6703    26.0
# Name: Age, Length: 6704, dtype: float64

# %%
df['Education Level']
# Out:
# 0              Bachelor's
# 1                Master's
# 2                     PhD
# 3              Bachelor's
# 4                Master's
#               ...
# 6699                  PhD
# 6700          High School
# 6701    Bachelor's Degree
# 6702      Master's Degree
# 6703          High School
# Name: Education Level, Length: 6704, dtype: object

# %%
df[df['Age']>40]
# Out:
#        Age  Gender    Education Level                         Job Title  \
# 2     45.0    Male                PhD                    Senior Manager
# 4     52.0    Male           Master's                          Director
# 6     42.0  Female           Master's                   Product Manager
# 11    48.0  Female         Bachelor's                        HR Manager
# 15    44.0    Male         Bachelor's                Operations Manager
# ...    ...     ...                ...                               ...
# 6690  42.0    Male  Bachelor's Degree                 Financial Manager
# 6693  43.0  Female    Master's Degree                     Sales Manager
# 6697  51.0  Female    Master's Degree  Senior Product Marketing Manager
# 6699  49.0  Female                PhD             Director of Marketing
# 6702  46.0    Male    Master's Degree                 Marketing Manager
#
#       Years of Experience    Salary
# 2                    15.0  150000.0
# ...

# %%
df[df['Education Level']=='PhD']
# Out:
#        Age  Gender Education Level                         Job Title  \
# 2     45.0    Male             PhD                    Senior Manager
# 9     38.0    Male             PhD                  Senior Scientist
# 17    39.0    Male             PhD                   Senior Engineer
# 28    43.0  Female             PhD                 Senior Consultant
# 34    46.0    Male             PhD                    Senior Manager
# ...    ...     ...             ...                               ...
# 6682  28.0    Male             PhD                 Marketing Manager
# 6685  49.0  Female             PhD  Senior Product Marketing Manager
# 6691  36.0  Female             PhD                 Marketing Manager
# 6696  28.0    Male             PhD              Sales Representative
# 6699  49.0  Female             PhD             Director of Marketing
#
#       Years of Experience    Salary
# 2                    15.0  150000.0
# 9                    10.0  110000.0
# ...

# %%
df[df['Years of Experience']>10]
# Out:
#        Age  Gender    Education Level                         Job Title  \
# 2     45.0    Male                PhD                    Senior Manager
# 4     52.0    Male           Master's                          Director
# 6     42.0  Female           Master's                   Product Manager
# 11    48.0  Female         Bachelor's                        HR Manager
# 13    40.0  Female           Master's                   Project Manager
# ...    ...     ...                ...                               ...
# 6690  42.0    Male  Bachelor's Degree                 Financial Manager
# 6693  43.0  Female    Master's Degree                     Sales Manager
# 6697  51.0  Female    Master's Degree  Senior Product Marketing Manager
# 6699  49.0  Female                PhD             Director of Marketing
# 6702  46.0    Male    Master's Degree                 Marketing Manager
#
#       Years of Experience    Salary
# 2                    15.0  150000.0
# ...

# %%
df[df['Job Title']=='Data Analyst']
# Out:
#        Age  Gender    Education Level     Job Title  Years of Experience  \
# 1     28.0  Female           Master's  Data Analyst                  3.0
# 81    41.0  Female           Master's  Data Analyst                 13.0
# 378   27.0  Female         Bachelor's  Data Analyst                  2.0
# 382   25.0  Female           Master's  Data Analyst                  1.0
# 386   30.0  Female         Bachelor's  Data Analyst                  5.0
# ...    ...     ...                ...           ...                  ...
# 3360  34.0    Male    Master's Degree  Data Analyst                  8.0
# 3367  35.0  Female    Master's Degree  Data Analyst                  9.0
# 3374  37.0    Male  Bachelor's Degree  Data Analyst                 11.0
# 3377  34.0    Male    Master's Degree  Data Analyst                  8.0
# 3384  35.0  Female    Master's Degree  Data Analyst                  9.0
#
#         Salary
# 1      65000.0
# 81     80000.0
# 378   110000.0
# 382   100000.0
# ...

# %%
df[(df['Gender']=='Female')&(df['Years of Experience']>5)]
# Out:
#        Age  Gender    Education Level                         Job Title  \
# 3     36.0  Female         Bachelor's                   Sales Associate
# 6     42.0  Female           Master's                   Product Manager
# 11    48.0  Female         Bachelor's                        HR Manager
# 13    40.0  Female           Master's                   Project Manager
# 16    33.0  Female           Master's                 Marketing Manager
# ...    ...     ...                ...                               ...
# 6691  36.0  Female                PhD                 Marketing Manager
# 6693  43.0  Female    Master's Degree                     Sales Manager
# 6695  33.0  Female  Bachelor's Degree         Content Marketing Manager
# 6697  51.0  Female    Master's Degree  Senior Product Marketing Manager
# 6699  49.0  Female                PhD             Director of Marketing
#
#       Years of Experience    Salary
# 3                     7.0   60000.0
# ...

# %%
df[(df['Education Level']=="Master's")&(df['Salary']>50000)]
# Out:
#        Age  Gender Education Level           Job Title  Years of Experience  \
# 1     28.0  Female        Master's        Data Analyst                  3.0
# 4     52.0    Male        Master's            Director                 20.0
# 6     42.0  Female        Master's     Product Manager                 12.0
# 10    29.0    Male        Master's  Software Developer                  3.0
# 13    40.0  Female        Master's     Project Manager                 14.0
# ...    ...     ...             ...                 ...                  ...
# 1182  33.0    Male        Master's      Data Scientist                 10.0
# 1185  30.0    Male        Master's   Software Engineer                  6.0
# 1190  28.0  Female        Master's      Data Scientist                  6.0
# 1194  31.0    Male        Master's      Data Scientist                  9.0
# 1197  28.0  Female        Master's      Data Scientist                  6.0
#
#         Salary
# 1      65000.0
# 4     200000.0
# ...

# %%
df[(df['Job Title']=="Data Analyst")&(df["Salary"]>40000)]
# Out:
#        Age  Gender    Education Level     Job Title  Years of Experience  \
# 1     28.0  Female           Master's  Data Analyst                  3.0
# 81    41.0  Female           Master's  Data Analyst                 13.0
# 378   27.0  Female         Bachelor's  Data Analyst                  2.0
# 382   25.0  Female           Master's  Data Analyst                  1.0
# 386   30.0  Female         Bachelor's  Data Analyst                  5.0
# ...    ...     ...                ...           ...                  ...
# 3360  34.0    Male    Master's Degree  Data Analyst                  8.0
# 3367  35.0  Female    Master's Degree  Data Analyst                  9.0
# 3374  37.0    Male  Bachelor's Degree  Data Analyst                 11.0
# 3377  34.0    Male    Master's Degree  Data Analyst                  8.0
# 3384  35.0  Female    Master's Degree  Data Analyst                  9.0
#
#         Salary
# 1      65000.0
# 81     80000.0
# 378   110000.0
# 382   100000.0
# ...

# %%
df[(df['Age']>50)|(df['Years of Experience']>20)]
# Out:
#        Age  Gender  Education Level                         Job Title  \
# 4     52.0    Male         Master's                          Director
# 19    51.0    Male       Bachelor's                    Sales Director
# 30    50.0    Male       Bachelor's                               CEO
# 39    49.0    Male       Bachelor's                   Sales Executive
# 50    51.0  Female       Bachelor's          Customer Service Manager
# ...    ...     ...              ...                               ...
# 6641  51.0  Female  Master's Degree  Senior Product Marketing Manager
# 6655  51.0  Female  Master's Degree         Content Marketing Manager
# 6669  51.0  Female  Master's Degree  Senior Product Marketing Manager
# 6683  51.0  Female  Master's Degree         Content Marketing Manager
# 6697  51.0  Female  Master's Degree  Senior Product Marketing Manager
#
#       Years of Experience    Salary
# 4                    20.0  200000.0
# 19                   22.0  180000.0
# ...

# %%
df[(df['Gender']=='Female')&(df['Salary']>15000)]
# Out:
#        Age  Gender    Education Level                         Job Title  \
# 1     28.0  Female           Master's                      Data Analyst
# 3     36.0  Female         Bachelor's                   Sales Associate
# 6     42.0  Female           Master's                   Product Manager
# 8     26.0  Female         Bachelor's             Marketing Coordinator
# 11    48.0  Female         Bachelor's                        HR Manager
# ...    ...     ...                ...                               ...
# 6695  33.0  Female  Bachelor's Degree         Content Marketing Manager
# 6697  51.0  Female    Master's Degree  Senior Product Marketing Manager
# 6699  49.0  Female                PhD             Director of Marketing
# 6701  30.0  Female  Bachelor's Degree                 Financial Manager
# 6703  26.0  Female        High School                   Sales Executive
#
#       Years of Experience    Salary
# 1                     3.0   65000.0
# ...

# %% [markdown]
# # **PREPROCESSING**

# %%
mean=df['Age'].mean()

df['Age'].fillna(mean,inplace=True)

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
df['Gender'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6699    False
# 6700    False
# 6701    False
# 6702    False
# 6703    False
# Name: Gender, Length: 6704, dtype: bool

# %%
df['Gender'].fillna(method='ffill')
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3       Female
# 4         Male
#          ...
# 6699    Female
# 6700      Male
# 6701    Female
# 6702      Male
# 6703    Female
# Name: Gender, Length: 6704, dtype: object

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
mesn=df['Salary'].mean()
df['Salary'].fillna(mean,inplace=True)

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 0
# dtype: int64

# %%
# df

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 0
# dtype: int64

# %%
# none='None'
# df['Education Level'].fillna(none,inplace=True)

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 0
# dtype: int64

# %%
# none='None'
# df['Job Title'].fillna(none,inplace=True)

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 0
# dtype: int64

# %%
df['Years of Experience'].fillna(0)
# Out:
# 0        5.0
# 1        3.0
# 2       15.0
# 3        7.0
# 4       20.0
#         ...
# 6699    20.0
# 6700     3.0
# 6701     4.0
# 6702    14.0
# 6703     1.0
# Name: Years of Experience, Length: 6704, dtype: float64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %% [markdown]
# # **VISUALIZATION**

# %%
import matplotlib.pyplot as plt

# %%
salary_df=df[(df['Age']>40)&(df['Age']<60)&(df['Salary']>80000)][['Age','Salary']]

x=salary_df['Age']
y=salary_df['Salary']

plt.title("Age V/S Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.scatter(x,y,color='g')
plt.show()

# %%
#bar 
edu_df=df[(df['Years of Experience']>10)&(df['Salary']>90000)][['Education Level','Salary']]

plt.title("Education Level v/s Salary")
plt.xlabel("Education level")
plt.ylabel("Salary")
x=edu_df['Education Level']
y=edu_df['Salary']


plt.bar(x,y)

plt.show()

# %%
#Age	Gender	Education Level	Job Title	Years of Experience	Salary

year_df=df[(df['Age']>40)&(df['Age']<60)&(df['Years of Experience']>20)][['Age','Years of Experience']].sort_values(by='Age')
x=year_df['Age']
y=year_df['Years of Experience']

plt.title("Age V/S Years of Experience")
plt.xlabel("Age")
plt.ylabel("Years of Experience")
plt.plot(x,y,color='c')
plt.show()

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
edu_catg= df['Education Level'].value_counts()
plt.figure(figsize=(10,7),dpi=100)
lb=edu_catg.index
x=edu_catg.values

plt.title("Education level")
plt.pie(x,labels=lb)
plt.legend(lb,loc="lower left")
plt.show()

# %%
x=df['Age']
plt.hist(x,bins=[30,40,50,60,70])
plt.title('Age distribution')
plt.xlabel("Age of a person")
plt.ylabel('counts')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6700 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6700 non-null   float64
#  1   Gender               6700 non-null   object
#  2   Education Level      6700 non-null   object
#  3   Job Title            6700 non-null   object
#  4   Years of Experience  6700 non-null   float64
#  5   Salary               6700 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 366.4+ KB

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %% [markdown]
# # **ENCODING**

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
df['Job Title'].unique()
# Out:
# array(['Software Engineer', 'Data Analyst', 'Senior Manager',
#        'Sales Associate', 'Director', 'Marketing Analyst',
#        'Product Manager', 'Sales Manager', 'Marketing Coordinator',
#        'Senior Scientist', 'Software Developer', 'HR Manager',
#        'Financial Analyst', 'Project Manager', 'Customer Service Rep',
#        'Operations Manager', 'Marketing Manager', 'Senior Engineer',
#        'Data Entry Clerk', 'Sales Director', 'Business Analyst',
#        'VP of Operations', 'IT Support', 'Recruiter', 'Financial Manager',
#        'Social Media Specialist', 'Software Manager', 'Junior Developer',
#        'Senior Consultant', 'Product Designer', 'CEO', 'Accountant',
#        'Data Scientist', 'Marketing Specialist', 'Technical Writer',
#        'HR Generalist', 'Project Engineer', 'Customer Success Rep',
#        'Sales Executive', 'UX Designer', 'Operations Director',
#        'Network Engineer', 'Administrative Assistant',
# ...

# %%
#map()
df['Gender']=df['Gender'].map({'Female':0,'Male':1,'Other':2})

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0       1         Bachelor's      Software Engineer
# 1     28.0       0           Master's           Data Analyst
# 2     45.0       1                PhD         Senior Manager
# 3     36.0       0         Bachelor's        Sales Associate
# 4     52.0       1           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0       0                PhD  Director of Marketing
# 6700  32.0       1        High School        Sales Associate
# 6701  30.0       0  Bachelor's Degree      Financial Manager
# 6702  46.0       1    Master's Degree      Marketing Manager
# 6703  26.0       0        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df['Education Level']=df['Education Level'].replace('phD','PhD')

#using apply()- df['Education Level']=df['Education Level'].apply(lamda x:'PhD' if x=='phD') 

#or map all the values, but only change for phD

# %% [markdown]
# **LABEL ENCODING**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['Education Level'].value_counts()
# Out:
# Bachelor's Degree    2266
# Master's Degree      1573
# PhD                  1369
# Bachelor's            756
# High School           448
# Master's              288
# Name: Education Level, dtype: int64

# %%
lb1=LabelEncoder()

df['Education Level']=lb1.fit_transform(df['Education Level'])

# %%
# df.drop('phD',axis=1,inplace=True)

# %%
# df

# %%
lb=LabelEncoder()

df['Job Title']=lb.fit_transform(df['Job Title'])

# %%
# df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6700 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6700 non-null   float64
#  1   Gender               6700 non-null   int64
#  2   Education Level      6700 non-null   int32
#  3   Job Title            6700 non-null   int32
#  4   Years of Experience  6700 non-null   float64
#  5   Salary               6700 non-null   float64
# dtypes: float64(3), int32(2), int64(1)
# memory usage: 314.1 KB

# %% [markdown]
# # **MACHINE LEARNING**

# %% [markdown]
# **LABELLING**

# %%
x=df.drop('Salary',axis=1)

y=df['Salary']

# %%
# x.shape

# %%
# y.shape

# %% [markdown]
# **SPLITTING**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (5360, 5)

# %%
x_test.shape
# Out:
# (1340, 5)

# %%
y_train.shape
# Out:
# (5360,)

# %%
y_test.shape
# Out:
# (1340,)

# %% [markdown]
# **MODEL BUILDING**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %% [markdown]
# **MODEL TRAINING**

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **MODEL TESTING**

# %%
lr_result= lr.predict(x_test)

# %%
y_test
# Out:
# 4204    122000.0
# 2232    190000.0
# 5560    160000.0
# 3083    136662.0
# 265      40000.0
#           ...
# 2924    140010.0
# 2157    185000.0
# 2202    150000.0
# 3288     60000.0
# 2913    156486.0
# Name: Salary, Length: 1340, dtype: float64

# %% [markdown]
# **Model Evaluation**

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, root_mean_squared_error

# %%
mae=mean_absolute_error(y_test, lr_result)
mse =mean_squared_error(y_test, lr_result)
rmse= root_mean_squared_error(y_test,lr_result)

print("MAE: ",mae)
print("MSE: ",mse)
print("RMSE: ",rmse)
# Out:
# MAE:  24175.816350504116
# MSE:  947572544.4966509
# RMSE:  30782.666299342083

# %%
#model score
train_score=lr.score(x_train,y_train)
print(train_score)

test_score=lr.score(x_test,y_test)
print(test_score)
# Out:
# 0.6703274242962294
# 0.6623865941638937

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt_result=dt.predict(x_test)

# %%
mae=mean_absolute_error(y_test, dt_result)
mse =mean_squared_error(y_test, dt_result)
rmse= root_mean_squared_error(y_test,dt_result)

print("MAE: ",mae)
print("MSE: ",mse)
print("RMSE: ",rmse)
# Out:
# MAE:  3449.157739861322
# MSE:  123815374.94741462
# RMSE:  11127.235728042011

# %%
#model score
train_score=dt.score(x_train,y_train)
print(train_score)

test_score=dt.score(x_test,y_test)
print(test_score)
# Out:
# 0.9966988382138428
# 0.9558854562918175

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_result= rf.predict(x_test)

# %%
mae=mean_absolute_error(y_test, rf_result)
mse =mean_squared_error(y_test, rf_result)
rmse= root_mean_squared_error(y_test,rf_result)

print("MAE: ",mae)
print("MSE: ",mse)
print("RMSE: ",rmse)
# Out:
# MAE:  3323.3308020272725
# MSE:  72007155.7123397
# RMSE:  8485.703018155873

# %%
#model score
train_score=rf.score(x_train,y_train)
print(train_score)

test_score=rf.score(x_test,y_test)
print(test_score)
# Out:
# 0.9941848592179434
# 0.9743443589350432

# %% [markdown]
# # **DEPLOYMENT**

# %%
x_test
# Out:
#        Age  Gender  Education Level  Job Title  Years of Experience
# 4204  40.0       0                4         94                 12.0
# 2232  43.0       0                5        158                 14.0
# 5560  36.0       0                5        114                 12.0
# 3083  38.0       1                1         43                 11.0
# 265   29.0       0                0         83                  1.5
# ...    ...     ...              ...        ...                  ...
# 2924  36.0       0                4        168                 13.0
# 2157  46.0       1                5        176                 16.0
# 2202  34.0       1                4         43                  9.0
# 3288  25.0       0                4        175                  2.0
# 2913  43.0       0                5        176                 19.0
#
# [1340 rows x 5 columns]

# %%
x_test.iloc[265].values
# Out:
# array([ 38.,   0.,   5., 161.,  12.])

# %%
y_test.iloc[265]
# Out:
# 140000.0

# %%
res= rf.predict([[38.,   0.,   5., 161.,  12.]])
print(res)
# Out:
# [140000.]
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Saving the model**

# %%
import pickle
with open("rf_salary_model.pkl","wb")as file:
    pickle.dump(rf,file)

# %%
with open("lb_salary.pkl","wb") as file:
    pickle.dump(lb,file)

# %%
with open("lb1_salary.pkl","wb")as file:
    pickle.dump(lb1,file)

# %% [markdown]
# **Loading the Model**

# %%
with open("rf_salary_model.pkl","rb")as file:
    salary_model=pickle.load(file)

# %%
with open("lb_salary.pkl","rb")as file:
    lb_salary=pickle.load(file)

# %%
with open("lb1_salary.pkl","rb")as file:
    lb1_salary=pickle.load(file)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %% [markdown]
# **Defining User functions**

# %%
def salaryPrediction(Age=33, Gender="Female", Education_Level="Bachelor's Degree", Job_Title="Software Engineer", Years_of_Experience=3):
    lst=[]

    lst=lst+[Age]

    if Gender=="Female":
        lst=lst+[0]
    elif Gender=="Male":
        lst=lst+[1]
    elif Gender=="Other":
        lst=lst+[2]

    Education_Level=lb1_salary.transform([Education_Level])
    lst=lst+list(Education_Level)

    Job_Title=lb_salary.transform([Job_Title])
    lst=lst+list(Job_Title)

    lst=lst+[Years_of_Experience]

    
    result=salary_model.predict([lst])
    return result[0]

# %%
(salaryPrediction())
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# 65350.0

# %% [markdown]
# **Calling function**

# %%
Age = float(input("Enter you Age:"))
Gender= input("Enter your Gender:(Female/Male/Other)")
Education_Level = (input("Enter you Education Level:(Bachelor\'s, Master\'s, PhD, Bachelor\'s Degree,Master\'s Degree, High School)"))
Job_Title = (input("Enter you  Job Title:(Software Engineer, Data Analyst, Senior Manager,Sales Associate, Director, Marketing Analyst,Product Manager,....)"))
Years_of_Experience = float(input("Enter you Years of Experience:"))

final_result=salaryPrediction(Age, Gender, Education_Level, Job_Title, Years_of_Experience)
print(final_result)
# Out:
# Enter you Age:45
# Enter your Gender:(Female/Male/Other)Male
# Enter you Education Level:(Bachelor's, Master's, PhD, Bachelor's Degree,Master's Degree, High School)PhD
# Enter you  Job Title:(Software Engineer, Data Analyst, Senior Manager,Sales Associate, Director, Marketing Analyst,Product Manager,....)Data Analyst
# Enter you Years of Experience:5
# 130614.28571428571
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
# !python --version
# Out:
# Python 3.9.7
